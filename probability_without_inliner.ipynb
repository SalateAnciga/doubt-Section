# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
#
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
def get_pdf_prob(dataset,startrange,endrange):
    #Pyplot functionsused for creating a figure, plotting lines, and decorating the plot with labels.
    from matplotlib import pyplot
    #SciPy provides functions for working with the normal distribution,computing probability density functions (PDF), cumulative distribution functions (CDF)
    from scipy.stats import norm
    #Seaborn is a Python data visualization library built on top of Matplotlib. 
    import seaborn as sns
    #The distplot function  is used for univariate distribution of observations.kde means kernel distibution providing a smooth curve that represents the distribution of the data.
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    #Draw verticalline based on startrange,endrange with red color
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    #generate sample
    sample=dataset
    #calculator parameter
    #Calculate mean and standard Divation
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean-%.3f,Standard Deviation-%.3f'%(sample_mean,sample_std))
    #define distribution
    #norm() functionis used to make the  distribution
    dist=norm(sample_mean,sample_std)
    #sample probabilites for arange of outcomkes
    #create a list usind inliner for loop 
    values=[]
    for i in range(60,70):
        values.append(i)
    #find probability distribution
    probabilites=[dist.pdf(i) for i in values]
    #find whole probabilities using sum()
    prob=sum(probabilites)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilites)))
    return prob

# %%
get_pdf_prob(dataset["ssc_p"],60,70)
# Out:
# C:\Users\jegat\AppData\Local\Temp\ipykernel_21792\4212891983.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean-71.721,Standard Deviation-8.715
# The area between range(60,70):0.3190485647827792
# 0.3190485647827792

# %%
#STANDARD NORMAL DISTRIBUTION

# %%
def stdNBdist(dataset):
    import seaborn as sns 
    sample=dataset
    sample_mean=sample.mean()
    sample_std=sample.std()
    values=[]
    for i in dataset:
        values.append(i) checking
    for j in values:
        values.append(j)

    values=[i for i in dataset]
    z_score=[((j-sample_mean)/sample_std) for j in values]
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBdist(dataset["ssc_p"])
